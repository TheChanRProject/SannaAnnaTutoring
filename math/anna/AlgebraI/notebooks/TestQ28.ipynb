# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt


x = [2.4,7.2,7,8.3,3.1,7.2,9]
y = [9,28,24,35,9,30,32]
figsize, ax = plt.subplots(figsize=(15,8))
ax.plot(x,y,'b')

# %%
45 * 3 + 15
# Out:
# 150
