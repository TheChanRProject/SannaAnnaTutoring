# %% [markdown]
# ## Question 5

# %% [markdown]
# Step 1: First we start by plotting the graph in a scatterplot fashion.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.array([-2,1,2,3,5,6,8])
y = np.array([11,7,-0.2,-1.5,-2.3,-1.8,1])

# plot 

plt.plot(x,y,'r-o')
plt.show()

# %% [markdown]
# Based on how the scatterplot is shown, it seems that the y values
