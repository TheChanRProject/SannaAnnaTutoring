# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt 

def basic_quadratic(a,x,h,k):
    return a*pow(x-h, 2) + k

xVals = np.arange(-10,11)
yVals = basic_quadratic(2,xVals,0,0)

plt.plot(xVals, yVals, 'b')
plt.show()
