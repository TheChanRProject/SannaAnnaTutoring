# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

xVals = np.array([-1,1,2,4,5])
yVals = np.array([0,-4,-3,5,12])

def quadratic(x):
    func = (x-1)**2 - 4
    return func 

yVals2 = quadratic(xVals)
    

# Plot

plt.plot(xVals,yVals,'r')
plt.plot(xVals, yVals2, 'g')
plt.show()

# %%
xRay = np.arange(0,5)
yRay = np.array([1,4,5,4,1])

# Function 

def quad2(x):
    return -(x-2)**2 + 5

yRay2 = quad2(xRay)
# Plot


plt.plot(xRay, yRay, 'b')
plt.plot(xRay,yRay2,'c')
plt.show()

# %%
# Problem 8

x = np.arange(0,5)

def soccer(t):
    return -8*t**2 + 32*t

y = soccer(x)

# plot 

plt.plot(x,y,'p')
plt.show()

# %%
# Problem 9

xV = np.arange(0,7)

def football(x):
    return -3*x**2 + 18*x + 7

yV = football(xV)

# plot

plt.plot(xV, yV, 'y')
plt.show()
