# %% [markdown]
# # Graphing Changes of State

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install xlrd==0.9.0
# Out:
# ...
#     100% |████████████████████████████████| 143kB 2.3MB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for xlrd ... done
#   Stored in directory: /Users/rchatter/Library/Caches/pip/wheels/64/9c/4f/218231860a48fec112b161d99cad27598ddaa3e81849bbac7a
# Successfully built xlrd
# ...

# %%
sci_df = pd.read_csv("custom-sci-data.csv")
sci_df.head()

plt.figure(figsize=(13,5))
plt.plot(sci_df['Temp'], sci_df['Time'], color='blue', marker='o') 
plt.title("Temperature versus Time Heat Curve")
plt.xlabel("Temperature")
plt.ylabel("Time")
plt.savefig('sci-heat-curve.png')
